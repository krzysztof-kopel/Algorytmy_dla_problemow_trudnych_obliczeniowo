# %% [markdown]
# # Reduction from X3C to SAT
# and solving X3C using a SAT solver.

# %%
class X3cInstance:
    def __init__(self, size: int, possible: bool, x3c: list[list[int]]):
        self.size = size
        self.possible = possible
        self.x3c = x3c

# %%
from dimacs import loadX3C
import os

# %%
for file_name in os.listdir("x3c"):
    print(loadX3C(f"x3c\\{file_name}"))
# Out:
# (30, [[1, 5, 11], [6, 10, 29], [6, 8, 17], [12, 14, 24], [10, 12, 23], [1, 16, 27], [2, 13, 24], [5, 16, 24], [17, 20, 27], [2, 8, 29], [3, 15, 29], [6, 13, 28], [1, 19, 30], [11, 20, 26], [2, 20, 26], [19, 21, 25], [3, 15, 28], [12, 18, 22], [4, 18, 21], [22, 23, 28], [5, 7, 26], [7, 19, 27], [8, 10, 30], [3, 18, 25], [4, 9, 23], [9, 13, 14], [15, 16, 22], [9, 14, 25], [7, 11, 30], [4, 17, 21]])
# (30, [[10, 22, 25], [30, 2, 27], [25, 7, 15], [5, 16, 22], [19, 10, 3], [2, 3, 18], [4, 13, 15], [23, 24, 26], [1, 14, 23], [19, 27, 28], [5, 12, 26], [17, 21, 30], [1, 24, 30], [8, 20, 29], [1, 18, 24], [9, 11, 14], [22, 4, 28], [17, 11, 29], [14, 12, 6], [7, 13, 20], [4, 15, 21], [2, 9, 29], [6, 8, 16], [9, 21, 8], [26, 23, 13], [3, 25, 27], [6, 10, 17], [5, 16, 20], [7, 19, 28], [11, 12, 18]])
# ...
